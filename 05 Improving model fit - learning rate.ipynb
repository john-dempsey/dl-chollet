# %%
from tensorflow import keras
from keras.datasets import mnist
from keras import layers

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(optimizer=keras.optimizers.RMSprop(1.0),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 11s 21ms/step - loss: 459.1177 - accuracy: 0.2788
# Epoch 2/10
# 469/469 [==============================] - 6s 14ms/step - loss: 3.5657 - accuracy: 0.2413
# Epoch 3/10
# 469/469 [==============================] - 6s 12ms/step - loss: 2.4604 - accuracy: 0.2114
# Epoch 4/10
# 469/469 [==============================] - 5s 11ms/step - loss: 2.5438 - accuracy: 0.2234
# Epoch 5/10
# 469/469 [==============================] - 5s 10ms/step - loss: 2.2948 - accuracy: 0.1961
# Epoch 6/10
# 469/469 [==============================] - 6s 12ms/step - loss: 2.3555 - accuracy: 0.2212
# Epoch 7/10
# 469/469 [==============================] - 5s 11ms/step - loss: 2.4247 - accuracy: 0.2409
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 3.0389 - accuracy: 0.2307
# Epoch 9/10
# 469/469 [==============================] - 6s 12ms/step - loss: 2.4754 - accuracy: 0.2265
# Epoch 10/10
# 469/469 [==============================] - 5s 11ms/step - loss: 2.3878 - accuracy: 0.2189

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(optimizer=keras.optimizers.RMSprop(0.01),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3138 - accuracy: 0.9187
# Epoch 2/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1183 - accuracy: 0.9666
# Epoch 3/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0948 - accuracy: 0.9748
# Epoch 4/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0841 - accuracy: 0.9793
# Epoch 5/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0746 - accuracy: 0.9825
# Epoch 6/10
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0656 - accuracy: 0.9843
# Epoch 7/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0578 - accuracy: 0.9869
# Epoch 8/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0514 - accuracy: 0.9887
# Epoch 9/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0468 - accuracy: 0.9897
# Epoch 10/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0410 - accuracy: 0.9909
